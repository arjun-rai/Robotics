# %%
import requests
from bs4 import BeautifulSoup
import urllib.request
import numpy as np

# %%
class BearerAuth(requests.auth.AuthBase):
    def __init__(self, token):
        self.token = token
    def __call__(self, r):
        r.headers["authorization"] = "Bearer " + self.token
        return r

# %%
eventNum = input('Enter Event Code After RE-VRC-XX- (RE-VRC-21-____): ')
# Out:
# Enter Event Code After RE-VRC-XX- (RE-VRC-21-____): 5119

# %%
response = requests.get('https://www.robotevents.com/api/v2/events/4'+str(eventNum)+'/teams?myTeams=false', auth=BearerAuth('eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..myHrCuO3q-_rZy16KF-_qJwo8Xa8gxfv8-oS_Q8rXD3ykNXpjTBOnQrE_EfRHatyGS59WBgKc64-sm0UJUfepxQoqKgX6-SdcKE0BM7mDt1IHHho8g4VKcX5TNhcHzx-olOvSQ-yvMzrYKPryFS2n_G65au2w2ENnTSZCGrnsnsMxojp9MR8zq-6GO6CsfSiy-yPIH66F_VEB4wLUzJfOn6q4QQL9TJIaEQrhorkv3jyKd-gUgczEZbCUn9XeeleoCxXh8uxvygyFybWdAxYDCZgDMXKMY-bWhUP-NWHUIV61YamconGBJGMHc4ERvZte10fa8nuBowZhuYLaArig3mNmjJYKPfBVqXCoP1FHe9NR8eijcUWGgV33yNr8se1kYNToL_UWzyjZ9iM33vJA01iob2LRFTUDhpKPfcWBFE7jQfpTbvGnHGQcP5UiEQi1-tpab9r8wCg22vCjb1lKod-Nlu3SzBTYuEaOEw7NI7JiZh8tGT_7xe8fewbfV7p9BOpIORYPKqOWYRJ035oMfi8SRxEu2V8p7O5__RCnhzs5tzLpXZxXQKvBHVaiLc8r0ulf2fRULe_cuezoyStRCsugGsnNyu440_cMfAbwApc8douVC23d8_8dVvPeMXe6NQXuIcnNUB6HmN2KzHreTh-05BSe3HDt0jNM5b9dhA'))

# %%
if response.status_code!=200:
    print('ERROR-CODE NOT VALID')

# %%
org = []
name = []
number = []
team_id = []
for j in range(response.json()['meta']['last_page']):
    if j!=0:
         response = requests.get(response.json()['meta']['next_page_url'], auth=BearerAuth('eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..myHrCuO3q-_rZy16KF-_qJwo8Xa8gxfv8-oS_Q8rXD3ykNXpjTBOnQrE_EfRHatyGS59WBgKc64-sm0UJUfepxQoqKgX6-SdcKE0BM7mDt1IHHho8g4VKcX5TNhcHzx-olOvSQ-yvMzrYKPryFS2n_G65au2w2ENnTSZCGrnsnsMxojp9MR8zq-6GO6CsfSiy-yPIH66F_VEB4wLUzJfOn6q4QQL9TJIaEQrhorkv3jyKd-gUgczEZbCUn9XeeleoCxXh8uxvygyFybWdAxYDCZgDMXKMY-bWhUP-NWHUIV61YamconGBJGMHc4ERvZte10fa8nuBowZhuYLaArig3mNmjJYKPfBVqXCoP1FHe9NR8eijcUWGgV33yNr8se1kYNToL_UWzyjZ9iM33vJA01iob2LRFTUDhpKPfcWBFE7jQfpTbvGnHGQcP5UiEQi1-tpab9r8wCg22vCjb1lKod-Nlu3SzBTYuEaOEw7NI7JiZh8tGT_7xe8fewbfV7p9BOpIORYPKqOWYRJ035oMfi8SRxEu2V8p7O5__RCnhzs5tzLpXZxXQKvBHVaiLc8r0ulf2fRULe_cuezoyStRCsugGsnNyu440_cMfAbwApc8douVC23d8_8dVvPeMXe6NQXuIcnNUB6HmN2KzHreTh-05BSe3HDt0jNM5b9dhA'))
    for i in range(len(response.json()['data'])):
        team = response.json()['data'][i]
        org.append(team['organization'])
        name.append(team['team_name'])
        number.append(team['number'])
        team_id.append(team['id'])

# %%
import pandas as pd

# %%
df = pd.DataFrame(number)

# %%
df['Name'] = name
df['Organization'] = org

# %%
df.columns = ['Number', 'Name', 'Organization']

# %%
#df

# %%
wins = []
losses = []
ties= []
rank = []
wp =[]
ap = []
sp = []
high_score = []
avg_points = []
for num in team_id:
    team_json = requests.get('https://www.robotevents.com/api/v2/teams/'+str(num)+'/rankings', auth=BearerAuth('eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..myHrCuO3q-_rZy16KF-_qJwo8Xa8gxfv8-oS_Q8rXD3ykNXpjTBOnQrE_EfRHatyGS59WBgKc64-sm0UJUfepxQoqKgX6-SdcKE0BM7mDt1IHHho8g4VKcX5TNhcHzx-olOvSQ-yvMzrYKPryFS2n_G65au2w2ENnTSZCGrnsnsMxojp9MR8zq-6GO6CsfSiy-yPIH66F_VEB4wLUzJfOn6q4QQL9TJIaEQrhorkv3jyKd-gUgczEZbCUn9XeeleoCxXh8uxvygyFybWdAxYDCZgDMXKMY-bWhUP-NWHUIV61YamconGBJGMHc4ERvZte10fa8nuBowZhuYLaArig3mNmjJYKPfBVqXCoP1FHe9NR8eijcUWGgV33yNr8se1kYNToL_UWzyjZ9iM33vJA01iob2LRFTUDhpKPfcWBFE7jQfpTbvGnHGQcP5UiEQi1-tpab9r8wCg22vCjb1lKod-Nlu3SzBTYuEaOEw7NI7JiZh8tGT_7xe8fewbfV7p9BOpIORYPKqOWYRJ035oMfi8SRxEu2V8p7O5__RCnhzs5tzLpXZxXQKvBHVaiLc8r0ulf2fRULe_cuezoyStRCsugGsnNyu440_cMfAbwApc8douVC23d8_8dVvPeMXe6NQXuIcnNUB6HmN2KzHreTh-05BSe3HDt0jNM5b9dhA')).json()
    n=0
    w=0
    l=0
    t=0
    r=0
    wpN=0
    apN=0
    spN=0
    hs=0
    avgp=0
    for i in range(len(team_json['data'])):
        if ('-21-' not in team_json['data'][i]['event']['code']):
            break
        else:
            n+=1
            w+=team_json['data'][i]['wins']
            l+=team_json['data'][i]['losses']
            t+=team_json['data'][i]['ties']
            r+=team_json['data'][i]['rank']
            wpN+=team_json['data'][i]['wp']
            apN+=team_json['data'][i]['ap']
            spN+=team_json['data'][i]['sp']
            if team_json['data'][i]['high_score']!=None:
                hs=max(team_json['data'][i]['high_score'], hs)
            if team_json['data'][i]['average_points']!=None:
                avgp+=team_json['data'][i]['average_points']
    wins.append(w)
    losses.append(l)
    ties.append(t)
    high_score.append(hs)
    if n==0:
        rank.append('N/A')
        wp.append('N/A')
        ap.append('N/A')
        sp.append('N/A')
        avg_points.append('N/A')   
    else:
        rank.append(int(r/n))
        wp.append(int(wpN/n))
        ap.append(int(apN/n))
        sp.append(int(spN/n))
        avg_points.append(int(avgp/n))

# %%
import warnings
df['Wins'] = wins
df['Losses'] = losses
df['Ties'] = ties
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    df['W:L Ratio'] = np.array(wins)/np.array(losses)   
df['Average Rank'] = rank
df['Average WP']=wp
df['Average AP'] = ap
df['Average SP'] = sp
df['High Score']=high_score
df['Average Points'] =avg_points

# %%
df
# Out:
#     Number                       Name  \
# 0      20X    Reseda Regents Robotics
# 1      20Y    Reseda Regents Robotics
# 2      20Z    Reseda Regents Robotics
# 3      62A                       null
# 4      62X                       null
# 5     599U                  Robodox U
# 6     599V                  Robodox V
# 7     599W                  Robodox W
# 8     884B   Manhattan Beach Robotics
# 9    1138A    Eagle Engineering Alpha
# 10   1138W        Eagle Engineering W
# 11   1138X        Eagle Engineering X
# 12   1437V           Patriot Robotics
# 13   1437X           Patriot Robotics
# 14   1437Z           Patriot Robotics
# 15   1469A           It Is What It Is
# 16   3324Z  Supernovas Minimal Effort
# 17   3759X                   Virtuoso
# 18   6149A                    CELTECH
# 19  28709A       Oak Park High School
# 20  52846A                  Crusaders
# 21  99999V       Mechanical Advantage
#
# ...

# %%
from selenium import webdriver
import json, time
from selenium.webdriver.common.by import By

def get_video_results(search):
    driver = webdriver.Chrome()
    driver.get('https://www.youtube.com/results?search_query='+search)
    youtube_data = []
    # scrolling to the end of the page
    # https://stackoverflow.com/a/57076690/15164646
    for i in range(1):
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    #print('Extracting results. It might take a while...')
    time.sleep(0.3)
    for result in driver.find_elements(By.CSS_SELECTOR, '.text-wrapper.style-scope.ytd-video-renderer'):
        title = result.find_element(By.CSS_SELECTOR, '.title-and-badge.style-scope.ytd-video-renderer').text
        link = result.find_element(By.CSS_SELECTOR, '.title-and-badge.style-scope.ytd-video-renderer a').get_attribute('href')

        try:
            time_published = result.find_element(By.CSS_SELECTOR, '.style-scope ytd-video-meta-block').text.split('\n')[1]
        except:
            time_published = None

        youtube_data.append({
            'title': title,
            'link': link,
            'time_published': time_published,
        })
    driver.quit()
    #print('Done!')
    return youtube_data

# %%
get_video_results('vex tipping point')[0]
# Out:
# {'title': 'Phantom Alliance | 2021-2022 VEX TIPPING POINT Worlds Reveal',
#  'link': 'https://www.youtube.com/watch?v=P8kBL5uM-2w',
#  'time_published': '3 months ago'}

# %%
links = [[0 for x in range(len(number))] for y in range(5)] 
print('Extracting results. It might take a while...')
for i in range(len(number)):
    removeWords =['school', 'high', 'senior', 'preparatory', 'foundation', 'stem', 'steam', 'magnet', 'academy', 'robotics', 'charter']
    data = get_video_results('vex tipping point ' + number[i])
    keywords = ['vex', 'tipping', 'point', number[i]]
    string = org[i].split(' ')
    for word in string:
        if word.lower() not in removeWords:
            keywords.append(word+' ')
    #print(keywords)
    #strLink = ''
    noResult = True
    for j in range(5):
        matches = 0
        for word in keywords:
            if word.lower() in data[j]['title'].lower():
                matches+=1
        #print(str(i),str(j))
        if matches>=4:
            #strLink+=data[i]['link']+' '
            links[j][i] = data[j]['link']
            #noResult = False
        else:
            links[j][i]='No Video'
#     if not noResult:
#         links.append(strLink)
#     else:
#         links.append('No Video')
print('Done!')
# Out:
# Extracting results. It might take a while...
# Done!

# %%
df["Link 1"]=links[0]
df["Link 2"]=links[1]
df["Link 3"]=links[2]
df["Link 4"]=links[3]
df["Link 5"]=links[4]

# %%
df
# Out:
#     Number                       Name  \
# 0      20X    Reseda Regents Robotics
# 1      20Y    Reseda Regents Robotics
# 2      20Z    Reseda Regents Robotics
# 3      62A                       null
# 4      62X                       null
# 5     599U                  Robodox U
# 6     599V                  Robodox V
# 7     599W                  Robodox W
# 8     884B   Manhattan Beach Robotics
# 9    1138A    Eagle Engineering Alpha
# 10   1138W        Eagle Engineering W
# 11   1138X        Eagle Engineering X
# 12   1437V           Patriot Robotics
# 13   1437X           Patriot Robotics
# 14   1437Z           Patriot Robotics
# 15   1469A           It Is What It Is
# 16   3324Z  Supernovas Minimal Effort
# 17   3759X                   Virtuoso
# 18   6149A                    CELTECH
# 19  28709A       Oak Park High School
# 20  52846A                  Crusaders
# 21  99999V       Mechanical Advantage
#
# ...

# %%
def make_hyperlink(url):
    return '=HYPERLINK("%s", "%s")' % (url, url)

# %%
df['Link 1'] = df['Link 1'].apply(lambda x: make_hyperlink(x))
df['Link 2'] = df['Link 2'].apply(lambda x: make_hyperlink(x))
df['Link 3'] = df['Link 3'].apply(lambda x: make_hyperlink(x))
df['Link 4'] = df['Link 4'].apply(lambda x: make_hyperlink(x))
df['Link 5'] = df['Link 5'].apply(lambda x: make_hyperlink(x))

# %%
df
# Out:
#     Number                       Name  \
# 0      20X    Reseda Regents Robotics
# 1      20Y    Reseda Regents Robotics
# 2      20Z    Reseda Regents Robotics
# 3      62A                       null
# 4      62X                       null
# 5     599U                  Robodox U
# 6     599V                  Robodox V
# 7     599W                  Robodox W
# 8     884B   Manhattan Beach Robotics
# 9    1138A    Eagle Engineering Alpha
# 10   1138W        Eagle Engineering W
# 11   1138X        Eagle Engineering X
# 12   1437V           Patriot Robotics
# 13   1437X           Patriot Robotics
# 14   1437Z           Patriot Robotics
# 15   1469A           It Is What It Is
# 16   3324Z  Supernovas Minimal Effort
# 17   3759X                   Virtuoso
# 18   6149A                    CELTECH
# 19  28709A       Oak Park High School
# 20  52846A                  Crusaders
# 21  99999V       Mechanical Advantage
#
# ...

# %%
df.to_excel('test.xlsx', index=False)
print('Saved to Excel Spreadsheet')
# Out:
# Saved to Excel Spreadsheet
