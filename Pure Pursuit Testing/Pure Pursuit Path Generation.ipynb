# %%
import math

# %%
class pathPoint():
    def __init__(self, x, y):
        self.x =x
        self.y =y
        self.w = 0
        self.curv = 0
        self.dist =0
        self.vel =0
        self.finVel =0

# %%
def distance(x1, y1, x2, y2):
    return math.sqrt((x2-x1)**2 + (y2-y1)**2)

def distance2(p1, p2):
    return distance(p1.x, p1.y, p2.x, p2.y)

# %%
class vect():
    def __init__(self, x1, y1, x2, y2):
        self.mag = distance(x1, y1, x2, y2)
        if (x2-x1==0):
            if (y2>y1):
                self.angle=90
            else:
                self.angle=-90
        elif (y2-y1==0):
            if (x2>x1):
                self.angle=0
            else:
                self.angle=180
        else:
            self.angle =  math.degrees(math.atan2(y2-y1,x2-x1))

# %%
def add(p, vec, t):
        x_temp =p.x + (vec.mag*math.cos(math.radians(vec.angle)))*t
        y_temp =p.y + (vec.mag*math.sin(math.radians(vec.angle)))*t
        return pathPoint(x_temp, y_temp)

# %%
points = []
points.append(pathPoint(0, 0))
points.append(pathPoint(50,20))
points.append(pathPoint(100, 100))
points.append(pathPoint(0, 100))

# %%
spacing = 1
newPoints = []

for i in range(0,len(points)-1):
    v = vect(points[i].x, points[i].y, points[i+1].x, points[i+1].y)
    num = math.ceil(v.mag/spacing)
    v.mag=spacing
    for j in range(0, num):
        newPoints.append(add(points[i],v,j))
newPoints.append(points[len(points)-1])

# %%
# for p in newPoints:
#     print(str(p.x)+ "\t" + str(p.y))

# %%
def copy(p):
    temp = []
    for t in p:
        temp.append(pathPoint(t.x, t.y))
    return temp

# %%
b = 0.75 #weight_smooth: b = 0.75 ~ 0.98
a = 1-b #weight_data: a = 1 - b
tol = 0.001
def smoother(path, a, b, tol):
    path_new = copy(path)
    change = tol
    while (change>=tol):
        change = 0.0
        for i in range(1, len(path)-1):
            aux = path_new[i].x
            path_new[i].x += a* (path[i].x-path_new[i].x) + b*(path_new[i-1].x + path_new[i+1].x - (2.0*path_new[i].x))
            change+= abs(aux-path_new[i].x)
            
            aux = path_new[i].y
            path_new[i].y += a* (path[i].y-path_new[i].y) + b*(path_new[i-1].y + path_new[i+1].y - (2.0*path_new[i].y))
            change+= abs(aux-path_new[i].y)
            
    return path_new

# %%
path_Smooth = smoother(newPoints, a, b, tol)

# %%
for p in path_Smooth:
    print(str(p.x)+ "\t" + str(p.y))
# Out:
# 0.0	0.0
# 0.0030038415633027106	0.9981421855478382
# 0.007004099728947676	1.995667572511869
# 0.01334151485879918	2.9917498107095195
# 0.024133644844901356	3.985080875546443
# 0.042977995671148975	4.973436620149966
# 0.07615246764467512	5.952935795521735
# 0.13471092521312875	6.916745790262361
# 0.23817012768215642	7.852804328656747
# 0.421016014784648	8.739798203233493
# 0.7441983749387041	9.540058775169456
# 1.3154462835698744	10.187005957689417
# 2.027034754937181	10.74721698073286
# 2.8180141160492562	11.258361760681508
# 3.6539226934490387	11.741721722993688
# 4.5151865652884755	12.209457968826058
# 5.390873232869758	12.6681386223952
# 6.274620553505414	13.122003026578483
# 7.162880706945091	13.572908919922272
# 8.053671070622581	14.022176003530147
# 8.945751079980072	14.47059686955902
# 9.838298313586227	14.918525966844275
# 10.730695660694973	15.366147692587603
# 11.622292798296545	15.813608013345647
# 12.512152919411136	16.26102059013932
# 13.398739232928932	16.7084600171624
# 14.279435495160273	17.15599622995765
# 15.149639313873312	17.603708223958247
# 16.00132466994599	18.051784908038865
# 16.820207923712246	18.50049542567823
# 17.58112483662525	18.950351758482505
# 18.23958240076268	19.402245216747673
# 18.716908801832606	19.857729213452014
# 18.874062800504888	20.319553125371414
# 18.655901347566218	20.88789125296811
# 18.22541233131028	21.516490352819876
# 17.674801509809782	22.179182411467004
# 17.056231497809428	22.861161973739883
# 16.399213395212104	23.554052897596524
# 15.720444101517877	24.25311698288965
# 15.029370276541549	24.955673887261316
# 14.331336190677899	25.66020696451305
# 13.629365389989845	26.36585774095315
# 12.925169329426046	27.072140267218778
# 12.219718290829992	27.778779579393415
# 11.513564695943694	28.485620089059132
# 10.80702681705954	29.192573474602717
# 10.100294523846074	29.899588946815513
# 9.393492512189631	30.606636164832754
# 8.686722035351098	31.313695148914466
# 7.980094882663101	32.020749749646654
# 7.273770790001297	32.72778239373974
# 6.568010700811886	33.434768293490436
# 5.863263667217465	34.14166718169688
# 5.160316430724725	34.84840984364803
# 4.460555599925009	35.554874992444894
# 3.7664298368799765	36.260848804771015
# 3.0822661017505535	36.96595363696545
# 2.4157120117507853	37.669522154077534
# 1.7802850788753224	38.37037490320327
# 1.1998785620012167	39.06642717874732
# 0.7167258846432267	39.7539941291573
# 0.4054784321774235	40.4265624748264
# 0.22939044920788698	41.24131829371878
# 0.12976595583901135	42.136513536892465
# 0.07339679473364583	43.07721329065524
# 0.041493242359113384	44.04365081423835
# 0.023420779641190534	45.02463861421668
# 0.013155245510710067	46.01383928950657
# 0.00727479159414531	47.007653063847535
# 0.0038192667166101002	48.00401785935324
# 0.0016368291264638982	49.00172194004236
# 0	50

# %%
path_Smooth[0].dist =0
for i in range(1, len(path_Smooth)):
    path_Smooth[i].dist = path_Smooth[i-1].dist + distance(path_Smooth[i].x, path_Smooth[i].y, path_Smooth[i-1].x, path_Smooth[i-1].y)

# %%
# for p in path_Smooth:
#     print(str(p.dist))

# %%
def area_of_triangle(a, b, c):
    return abs((b.x-a.x)*(c.y-a.y) - (b.y-a.y)*(c.x-a.x));

# %%
path_Smooth[0].curv=0.0001 #add to not /0 error
path_Smooth[-1].curv=0.0001
for i in range(1, len(path_Smooth)-1): #Menger curvature
    path_Smooth[i].x+=0.0001
    path_Smooth[i].y+=0.0001
    p1 = path_Smooth[i-1]
    p2 = path_Smooth[i]
    p3 = path_Smooth[i+1]
    temp = (4*area_of_triangle(p1, p2, p3))
    path_Smooth[i].curv = temp/(distance2(p1, p2)* distance2(p2, p3)* distance2(p3, p1))
    if (path_Smooth[i].curv==0):
        path_Smooth[i].curv+=0.001

# %%
# for p in path_Smooth:
#     print(str(p.curv))

# %%
max_vel = 200 #speed
turning_const = 5 #changes how fast it goes around turns
for p in path_Smooth:
    p.vel = min(max_vel, turning_const/p.curv)

# %%
#max accel
max_accel = 70
starting_vel = 36
path_Smooth[-1].vel =0
for i in range(len(path_Smooth)-2, -1, -1):
    d = distance2(path_Smooth[i+1], path_Smooth[i])
    path_Smooth[i].finVel = min(path_Smooth[i].vel, math.sqrt(path_Smooth[i+1].finVel**2 + 2*max_accel*d))


path_Smooth[0].finVel = starting_vel
for i in range(1, len(path_Smooth)):
    d = distance2(path_Smooth[i-1], path_Smooth[i])
    test = math.sqrt(path_Smooth[i-1].finVel**2 + 2*max_accel*d)
    if (test<path_Smooth[i].finVel):
        path_Smooth[i].finVel=test
    else:
        break

# %% [markdown]
# TO DO: RATE LIMITER

# %%
# for p in path_Smooth:
#     print(str(p.curv))
# Out:
# 0	36
#
# 1	35.1864524874173
#
# 2	33.1425973869799
#
# 3	30.967360652475563
#
# 4	28.633946100815603
#
# 5	26.105706594861314
#
# 6	23.33022512136542
#
# 7	20.22664541517901
#
# 8	16.65145551747843
#
# 9	12.267062983962848
#
# 10	6.385266962913162
#
# 11	12.261071337413693
#
# 12	24.77152285757305
#
# 13	48.186731712875634
#
# 14	49.08261545968739
#
# 15	47.664370729503595
#
# 16	46.18978644123506
#
# 17	44.65880866814907
#
# 18	43.0691034442652
#
# 19	41.41586246986055
#
# 20	39.69246367676623
#
# 21	37.89039626939342
#
# 22	35.9987588609182
#
# 23	34.003667681691084
#
# 24	31.887434809182636
#
# 25	29.627271611783875
#
# 26	27.193224880699077
#
# 27	24.545150663635646
#
# 28	21.627152796436416
#
# 29	18.357753133594098
#
# 30	14.603228579389715
#
# 31	10.072200564861943
#
# 32	3.0133691869106
#
# 33	2.0148287555138586
#
# 34	7.334511141997353
#
# 35	21.8360359089213
#
# 36	51.1589466836717
#
# 37	58.436150550035336
#
# 38	57.280907273694396
#
# 39	56.07752666559323
#
# 40	54.833583780581236
#
# 41	53.55252892598572
#
# 42	52.23528933027435
#
# 43	50.88118554399107
#
# 44	49.48843481150952
#
# 45	48.0544054559955
#
# 46	46.57571665076178
#
# 47	45.048235151553136
#
# 48	43.46699386042012
#
# 49	41.82603945452653
#
# 50	40.11820305615215
#
# 51	38.33477559972296
#
# 52	36.46505518976734
#
# 53	34.49571380736726
#
# 54	32.40989949321822
#
# 55	30.18593602011272
#
# 56	27.795377029824238
#
# 57	25.199936299815615
#
# 58	22.34618725712935
#
# 59	19.154860581798538
#
# 60	15.492842427198868
#
# 61	11.062524191621996
#
# 62	8.947201939697516
#
# 63	21.283539847938336
#
# 64	33.18461423830101
#
# 65	31.13333299663893
#
# 66	28.87749066943989
#
# 67	26.392193377407082
#
# 68	23.623131031138975
#
# 69	20.467436470618175
#
# 70	16.71598173650912
#
# 71	11.821384857097405
#
# 72	0

# %%
f = open("data.csv", "w")
for p in path_Smooth:
    f.write(str(p.x) + "," + str(p.y) + "," + str(p.finVel) + "\n")
    print(str(p.x) + "\t" + str(p.y))
# Out:
# 0.0	0.0
# 0.9285766908852593	0.3714906763541037
# 1.8570533378922076	0.7428813351568834
# 2.7855304576319506	1.114272385653948
# 3.714005576864447	1.4856600696666595
# 4.642484244805225	1.8570632680133436
# 5.570963933060549	2.228423808137235
# 6.499427759688273	2.5998548146115725
# 7.427918205020484	2.971224308280447
# 8.35639603804955	3.3426024446753315
# 9.28486292907254	3.7140085296490883
# 10.213338365536453	4.085407365679686
# 11.141821452136732	4.4567899967905
# 12.07030149802763	4.828172555819662
# 12.998775531485713	5.199564583961496
# 13.927248295150921	5.570961388677369
# 14.85572407524156	5.942355259790837
# 15.784202771581187	6.3137442066467075
# 16.712681760459258	6.685131334655083
# 17.64115910031374	7.056520116782048
# 18.569634802000838	7.42791147799272
# 19.498110072037363	7.799304108080834
# 20.42658600587146	8.170696268017654
# 21.35506289096048	8.54208713605805
# 22.28354031853498	8.913476994578081
# 23.21201768572275	9.28486664582459
# 24.14049461658006	9.656256747998599
# 25.06897108869668	10.027647497403741
# 25.997447313468363	10.399038693513969
# 26.925923531818583	10.77042999626058
# 27.85439986111866	11.141821166318444
# 28.782876242447	11.513212180075094
# 29.711352461552412	11.884603223974228
# 30.639828182538256	12.255994637774727
# 31.568302934672133	12.627386886655898
# 32.496776007309585	12.99878062290666
# 33.425246212982614	13.370176879998855
# 34.35371145822231	13.741577448063785
# 35.282168004114695	14.11298552405437
# 36.210609189093105	14.484406824518643
# 37.13902319611067	14.855851516283549
# 38.06738911798251	15.227337607000003
# 38.99567000206174	15.598896933332188
# 39.92380054782615	15.97058575338842
# 40.8516653509599	16.342503482829397
# 41.77906043976009	16.714825824475827
# 42.70562528335884	17.08786333494997
# 43.63072261012594	17.462164948191546
# 44.55322597829262	17.838700960367976
# 45.47114429095175	18.21918646827639
# 46.38095809471647	18.606653072338386
# 47.27644642827977	19.006459411416476
# 48.14661316981308	19.42807737489677
# 48.97202166486669	19.88824939703048
# 49.71831584335092	20.41656926596907
# 50.37068196672635	21.0837122256052
# 50.969909094181055	21.82939316447811
# 51.53907328797712	22.6195062952936
# 52.09122963376185	23.434756559547385
# 52.63376393516415	24.26422794208368
# 53.170854647748456	25.101744800156393
# 53.70486569710928	25.94381331647449
# 54.237134453855	26.788456893812402
# 54.76841752379226	27.634557289380542
# 55.299142949982425	28.48148186713535
# 55.82955289395206	29.32887271888408
# 56.359784356397526	30.17652736130405
# 56.889914844240636	31.024331241281953
# 57.419988206366	31.872219551391286
# 57.95002924994992	32.72015562734469
# 58.48005200950298	33.5681187265628
# 59.010064424992244	34.416097114028524
# 59.5400709884365	35.26408415068628
# 60.070074241188806	36.1120760804981
# 60.600075621010674	36.96007077849268
# 61.13007594130035	37.80806704248239
# 61.660075662217324	38.656064192352446
# 62.19007504407436	39.504061843355004
# 62.72007423412264	40.35205977784591
# 63.25007331565295	41.200057872715796
# 63.780072335776026	42.04805605833186
# 64.31007132113949	42.89605429530868
# 64.84007028681864	43.74405256136673
# 65.37006924134532	44.59205084389923
# 65.90006818955118	45.44004913576867
# 66.43006713417503	46.288047432930476
# 66.96006607677114	47.13604573309017
# 67.49006501822255	47.98404403494446
# 68.020063959031	48.83204233775261
# 68.55006289948125	49.6800406410938
# 69.08006183973421	50.52803894472973
# 69.61006077987986	51.376037248526494
# 70.14005971996781	52.22403555240986
# 70.67005866002465	53.072033856339594
# 71.20005760006427	53.92003216029462
# 71.73005654009344	54.76803046426433
# 72.26005548011545	55.61602876824361
# 72.7900543086695	56.46402689389009
# 73.32005417314952	57.31202718672083
# 73.85005104499307	58.160016235277425
# 74.38004545701268	59.00803680693943
# 74.9100775207827	59.8560092781768
# 75.44000676075888	60.70401046695888
# 75.97006236424299	61.552032301679176
# 76.50007478616902	62.40001948030891
# 77.03003309673997	63.24800140264658
# 77.5600217989838	64.09600511608497
# 78.0900456180182	64.94401655094539
# 78.6200607813649	65.79201701520518
# 79.15005100497021	66.64000744785085
# 79.68003370091523	67.48799913058278
# 80.2100274298509	68.33599805054958
# 80.74003352525395	69.1840014341735
# 81.27004193974855	70.03200365823875
# 81.80004428170473	70.88000198695383
# 82.33003982923042	71.72799758132797
# 82.86003310670809	72.57599317014282
# 83.39002866930858	73.42399056440797
# 83.92002800983049	74.27198979604792
# 84.45002972690193	75.11998974459003
# 84.98003143965025	75.96798922553819
# 85.5100315348235	76.81598769185294
# 86.04002978838733	77.66398530147708
# 86.57002696942712	78.51198256775245
# 87.10002404525204	79.35997994041402
# 87.63002154706882	80.20797754920574
# 88.16001932523668	81.05597515459206
# 88.69001661395117	81.90397221592679
# 89.22001217397175	82.75196794317586
# 89.75000427752857	83.59996121586626
# 90.27999035696368	84.44795028184232
# 90.80996616777334	85.29593214477116
# 91.3399242529567	86.14390148357509
# 91.86985129455232	86.9918487946174
# 92.3997235473909	87.8397571703856
# 92.92949886828418	88.68759665014456
# 93.45910267948005	89.53531425056649
# 93.98840316047334	90.38281633636811
# 94.51716736732595	91.22993743871262
# 95.04498362950001	92.07638511789195
# 95.57112434655781	92.92164248871897
# 96.09430345200059	93.76479591996275
# 96.61224770735463	94.60423047962382
# 97.12093893461049	95.4370916129919
# 97.6132746057475	96.25833361632344
# 98.07670032328795	97.0590377320315
# 98.48902501915165	97.82343923000384
# 98.81102393601861	98.52367250068751
# 98.97336371523123	99.11048252259562
# 98.8534912843329	99.49680652535663
# 98.35141593826106	99.71536602869367
# 97.63311255340003	99.83901419749509
# 96.7924799999453	99.9089670885483
# 95.88264076371749	99.9485423350219
# 94.93364843906879	99.97093168951973
# 93.9625055913441	99.98359827378627
# 92.97883127692845	99.99076428518842
# 91.98806739445652	99.99481839552396
# 90.99329265087987	99.9971119750247
# 89.99624879754005	99.99840954942007
# 88.99792121466797	99.9991436422672
# 87.99886737222516	99.99955894986721
# 86.99940265385291	99.99979390699426
# 85.99970548515306	99.99992683198228
# 84.9998768090451	100.00000203287088
# 83.99997373336122	100.00004457669144
# 83.00002856661408	100.00006864502954
# 82.00005958726966	100.00008226109131
# 81.00007713634494	100.00008996399134
# 80.00008706423873	100.00009432171035
# 79.00009268075807	100.00009678704657
# 78.00009585834877	100.00009818187476
# 77.00009765626064	100.00009897112314
# 76.00009867368276	100.00009941778303
# 75.00009924954024	100.00009967061011
# 74.00009957553516	100.00009981374345
# 73.00009976010023	100.00009989477698
# 72.00009986457736	100.00009994063842
# 71.0000999236809	100.00009996657002
# 70.00009995706844	100.0000999812058
# 69.00009997588185	100.00009998944168
# 68.0000999864435	100.00009999405705
# 67.00009999234489	100.00009999663115
# 66.00009999562714	100.00009999806122
# 65.00009999744891	100.00009999885593
# 64.0000999984652	100.000099999302
# 63.000099999043144	100.00009999955918
# 62.00009999938518	100.00009999971493
# 61.000099999600366	100.00009999981566
# 60.00009999974546	100.00009999988526
# 59.00009999984875	100.00009999993534
# 58.0000999999238	100.00009999997155
# 57.00009999997718	100.0000999999967
# 56.00010000001269	100.00010000001265
# 55.0001000000332	100.00010000002095
# 54.00010000004164	100.00010000002331
# 53.00010000004106	100.00010000002138
# 52.00010000003447	100.00010000001686
# 51.00010000002467	100.0001000000111
# 50.000100000014	100.00010000000532
# 49.000100000004174	100.00010000000032
# 48.00009999999628	100.00009999999654
# 47.00009999999087	100.00009999999415
# 46.000099999987924	100.00009999999307
# 45.00009999998748	100.00009999999325
# 44.00009999998774	100.00009999999375
# 43.00009999999223	100.00009999999628
# 42.000099999989615	100.00009999999511
# 41.00010000000229	100.00010000000167
# 40.00009999999113	100.00009999999591
# 39.00010000000675	100.00010000000401
# 38.00010000000088	100.0001000000007
# 37.00009999999978	100.00010000000017
# 36.00010000000668	100.00010000000363
# 35.00010000000336	100.0001000000017
# 34.00009999999994	100.00009999999995
# 33.00010000000269	100.0001000000014
# 32.00010000000308	100.00010000000148
# 31.000099999999836	100.00009999999978
# 30.000099999998785	100.00009999999932
# 29.000100000000202	100.00010000000009
# 28.000100000000394	100.00010000000017
# 27.000099999999012	100.00009999999943
# 26.00009999999842	100.00009999999918
# 25.00009999999922	100.00009999999963
# 24.00009999999997	100.00010000000003
# 23.00009999999982	100.00009999999995
# 22.000099999999403	100.00009999999975
# 21.00009999999951	100.00009999999983
# 20.000100000000028	100.00010000000009
# 19.000100000000355	100.00010000000023
# 18.00010000000027	100.00010000000017
# 17.000100000000042	100.00010000000005
# 16.00009999999999	100.00010000000003
# 15.000100000000124	100.00010000000012
# 14.000100000000247	100.00010000000017
# 13.000100000000216	100.00010000000013
# 12.000100000000078	100.00010000000005
# 11.000099999999964	100.00009999999999
# 10.00009999999995	100.00009999999997
# 9.000099999999996	100.00009999999999
# 8.000100000000028	100.0001
# 7.00010000000001	100.00010000000002
# 6.000099999999964	100.00009999999997
# 5.000099999999932	100.00009999999996
# 4.000099999999938	100.00009999999996
# 3.0000999999999673	100.0001
# 2.0000999999999958	100.00010000000003
# 1.0001000000000067	100.00010000000003
# 0	100
